# %%
from keras.layers.normalization.batch_normalization import BatchNormalization
# !pip install imagecodecs-lite
# !pip install imagecodecs
# !pip uninstall tiffile
import imagecodecs
from skimage.io import imread, imshow
import numpy as np
import matplotlib.pyplot as plt
import csv
from random import shuffle

from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf


def load_data(path):
    info = []
    images_list = []
    images_class = []
    print('Loading ', path, 'in memory...')
    with open(path, newline='') as csv_file:
        images_reader = csv.reader(csv_file)
        next(images_reader)
        for row in images_reader:
            info.append(row)
    shuffle(info)

    for elem in info:
        images_list.append(imread('/content/drive/MyDrive/Colab Notebooks/Train&Validation/' + elem[0])[55:455, 55:455].reshape(400, 400, 1))
        images_class.append(elem[1] == 'covid')
    return np.array(images_list), np.array(images_class)


def create_model():
    model = Sequential()
    model.add(Conv2D(32, 3, padding="same", activation="relu", input_shape=(400, 400, 1)))
    model.add(BatchNormalization())
    model.add(MaxPool2D())
    model.add(Conv2D(64, 3, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D())
    model.add(Conv2D(128, 3, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D())
    model.add(Dropout(0.25))
    

    model.add(Conv2D(256, 3, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D())

    model.add(Conv2D(128, 3, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D())
    model.add(Dropout(0.25))
    model.add(Conv2D(128, 3, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D())
    model.add(Conv2D(128, 3, padding="same", activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPool2D())

    model.add(Flatten())
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.25))
    model.add(Dense(1, activation="sigmoid"))

    return model


datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 60,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=True)  # randomly flip images


Adam = tf.keras.optimizers.Adam(learning_rate=0.000001)
def run_model2(path, epochs_number, folder): #Save acc, loss,... in a file to allow interruption
    try:
        my_model = load_model('/content/drive/MyDrive/Colab Notebooks/' + path)
        print('\033[94m'+'\033[1m' + 'Model Loaded' + '\033[0m')
        my_model.summary()
    except OSError:
        print('\033[91m'+'\033[1m'+'Model', path, 'not found. Creating a new one'+'\033[0m')
        my_model = create_model()
        my_model.summary()
        my_model.compile(loss=tf.keras.losses.BinaryCrossentropy(reduction='sum_over_batch_size'),
                         optimizer=Adam, metrics=["accuracy"])

    train_images, train_classes = load_data('/content/drive/MyDrive/Colab Notebooks/CSV/train' + str(folder) + '.csv')
    validation_images, validation_classes = load_data('/content/drive/MyDrive/Colab Notebooks/CSV/validation' + str(folder) + '.csv')
    datagen.fit(train_images)
    history = my_model.fit(train_images, train_classes, epochs=epochs_number, validation_data=(validation_images,
                                                                                               validation_classes))
    my_model.save('/content/drive/MyDrive/Colab Notebooks/' + path)
    return history.history['accuracy'], history.history['val_accuracy'], history.history['loss'], history.history['val_loss'], epochs_number


def plot_accuracy(accuracy, validation_accuracy, loss, validation_loss, epochs): #Add save as png
    epochs_range = range(epochs)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, accuracy, label='Training Accuracy')
    plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, validation_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()


accuracy, validation_accuracy, loss, validation_loss, epochs = run_model2('18-06-22-1.h5', 100, 3)

plot_accuracy(accuracy, validation_accuracy, loss, validation_loss, epochs)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imagecodecs-lite
#   Downloading imagecodecs_lite-2020.1.31-py3-none-any.whl (1.4 kB)
# Collecting imagecodecs
#   Downloading imagecodecs-2021.11.20-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      |████████████████████████████████| 31.0 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from imagecodecs->imagecodecs-lite) (1.21.6)
# Installing collected packages: imagecodecs, imagecodecs-lite
# Successfully installed imagecodecs-2021.11.20 imagecodecs-lite-2020.1.31
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.7/dist-packages (2021.11.20)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from imagecodecs) (1.21.6)
# WARNING: Skipping tiffile as it is not installed.
# Model Loaded
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 400, 400, 32)      320
#
#  batch_normalization (BatchN  (None, 400, 400, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 200, 200, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 200, 200, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 200, 200, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 100, 100, 64)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 100, 100, 128)     73856
#
#  batch_normalization_2 (Batc  (None, 100, 100, 128)    512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 50, 50, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 50, 50, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 50, 50, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 25, 25, 256)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 128)       295040
#
#  batch_normalization_4 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 128)         147584
#
#  batch_normalization_6 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 256)               295168
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1,276,929
# Trainable params: 1,275,201
# Non-trainable params: 1,728
# _________________________________________________________________
# Loading  /content/drive/MyDrive/Colab Notebooks/CSV/train3.csv in memory...
# Loading  /content/drive/MyDrive/Colab Notebooks/CSV/validation3.csv in memory...
# Epoch 1/100
# 117/117 [==============================] - 47s 279ms/step - loss: 0.1489 - accuracy: 0.9431 - val_loss: 0.6310 - val_accuracy: 0.7433
# Epoch 2/100
# 117/117 [==============================] - 28s 242ms/step - loss: 0.1467 - accuracy: 0.9440 - val_loss: 0.6322 - val_accuracy: 0.7444
# Epoch 3/100
# 117/117 [==============================] - 28s 243ms/step - loss: 0.1570 - accuracy: 0.9370 - val_loss: 0.6374 - val_accuracy: 0.7411
# Epoch 4/100
# 117/117 [==============================] - 28s 238ms/step - loss: 0.1504 - accuracy: 0.9389 - val_loss: 0.6380 - val_accuracy: 0.7433
# Epoch 5/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1469 - accuracy: 0.9440 - val_loss: 0.6418 - val_accuracy: 0.7433
# Epoch 6/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1452 - accuracy: 0.9442 - val_loss: 0.6482 - val_accuracy: 0.7377
# Epoch 7/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1404 - accuracy: 0.9461 - val_loss: 0.6460 - val_accuracy: 0.7411
# Epoch 8/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1449 - accuracy: 0.9461 - val_loss: 0.6413 - val_accuracy: 0.7455
# Epoch 9/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1533 - accuracy: 0.9431 - val_loss: 0.6489 - val_accuracy: 0.7433
# Epoch 10/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1375 - accuracy: 0.9493 - val_loss: 0.6507 - val_accuracy: 0.7400
# Epoch 11/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1409 - accuracy: 0.9477 - val_loss: 0.6527 - val_accuracy: 0.7377
# Epoch 12/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1375 - accuracy: 0.9474 - val_loss: 0.6475 - val_accuracy: 0.7422
# Epoch 13/100
# 117/117 [==============================] - 28s 243ms/step - loss: 0.1505 - accuracy: 0.9434 - val_loss: 0.6467 - val_accuracy: 0.7411
# Epoch 14/100
# 117/117 [==============================] - 28s 244ms/step - loss: 0.1438 - accuracy: 0.9458 - val_loss: 0.6547 - val_accuracy: 0.7400
# Epoch 15/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1419 - accuracy: 0.9480 - val_loss: 0.6562 - val_accuracy: 0.7422
# Epoch 16/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1310 - accuracy: 0.9525 - val_loss: 0.6531 - val_accuracy: 0.7422
# Epoch 17/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1417 - accuracy: 0.9440 - val_loss: 0.6511 - val_accuracy: 0.7422
# Epoch 18/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1386 - accuracy: 0.9448 - val_loss: 0.6480 - val_accuracy: 0.7422
# Epoch 19/100
# 117/117 [==============================] - 28s 243ms/step - loss: 0.1342 - accuracy: 0.9541 - val_loss: 0.6494 - val_accuracy: 0.7433
# Epoch 20/100
# 117/117 [==============================] - 29s 248ms/step - loss: 0.1402 - accuracy: 0.9440 - val_loss: 0.6524 - val_accuracy: 0.7411
# Epoch 21/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1408 - accuracy: 0.9453 - val_loss: 0.6572 - val_accuracy: 0.7400
# Epoch 22/100
# 117/117 [==============================] - 29s 248ms/step - loss: 0.1380 - accuracy: 0.9488 - val_loss: 0.6571 - val_accuracy: 0.7400
# Epoch 23/100
# 117/117 [==============================] - 28s 242ms/step - loss: 0.1346 - accuracy: 0.9509 - val_loss: 0.6506 - val_accuracy: 0.7433
# Epoch 24/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1342 - accuracy: 0.9501 - val_loss: 0.6558 - val_accuracy: 0.7411
# Epoch 25/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1359 - accuracy: 0.9485 - val_loss: 0.6530 - val_accuracy: 0.7455
# Epoch 26/100
# 117/117 [==============================] - 29s 248ms/step - loss: 0.1326 - accuracy: 0.9482 - val_loss: 0.6541 - val_accuracy: 0.7422
# Epoch 27/100
# 117/117 [==============================] - 29s 248ms/step - loss: 0.1260 - accuracy: 0.9555 - val_loss: 0.6581 - val_accuracy: 0.7433
# Epoch 28/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1306 - accuracy: 0.9509 - val_loss: 0.6602 - val_accuracy: 0.7422
# Epoch 29/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1323 - accuracy: 0.9541 - val_loss: 0.6491 - val_accuracy: 0.7455
# Epoch 30/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1339 - accuracy: 0.9493 - val_loss: 0.6530 - val_accuracy: 0.7433
# Epoch 31/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1246 - accuracy: 0.9576 - val_loss: 0.6630 - val_accuracy: 0.7377
# Epoch 32/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1244 - accuracy: 0.9558 - val_loss: 0.6529 - val_accuracy: 0.7433
# Epoch 33/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1227 - accuracy: 0.9590 - val_loss: 0.6581 - val_accuracy: 0.7433
# Epoch 34/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1269 - accuracy: 0.9504 - val_loss: 0.6564 - val_accuracy: 0.7433
# Epoch 35/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1280 - accuracy: 0.9531 - val_loss: 0.6596 - val_accuracy: 0.7433
# Epoch 36/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1241 - accuracy: 0.9566 - val_loss: 0.6574 - val_accuracy: 0.7422
# Epoch 37/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1220 - accuracy: 0.9549 - val_loss: 0.6573 - val_accuracy: 0.7422
# Epoch 38/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1318 - accuracy: 0.9482 - val_loss: 0.6605 - val_accuracy: 0.7433
# Epoch 39/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1264 - accuracy: 0.9512 - val_loss: 0.6581 - val_accuracy: 0.7411
# Epoch 40/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1276 - accuracy: 0.9504 - val_loss: 0.6575 - val_accuracy: 0.7422
# Epoch 41/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1264 - accuracy: 0.9528 - val_loss: 0.6562 - val_accuracy: 0.7433
# Epoch 42/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1185 - accuracy: 0.9582 - val_loss: 0.6592 - val_accuracy: 0.7433
# Epoch 43/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1213 - accuracy: 0.9552 - val_loss: 0.6587 - val_accuracy: 0.7433
# Epoch 44/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1205 - accuracy: 0.9541 - val_loss: 0.6591 - val_accuracy: 0.7467
# Epoch 45/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1197 - accuracy: 0.9536 - val_loss: 0.6688 - val_accuracy: 0.7400
# Epoch 46/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1180 - accuracy: 0.9574 - val_loss: 0.6587 - val_accuracy: 0.7467
# Epoch 47/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1183 - accuracy: 0.9563 - val_loss: 0.6640 - val_accuracy: 0.7411
# Epoch 48/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1177 - accuracy: 0.9563 - val_loss: 0.6719 - val_accuracy: 0.7400
# Epoch 49/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1169 - accuracy: 0.9558 - val_loss: 0.6755 - val_accuracy: 0.7411
# Epoch 50/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1232 - accuracy: 0.9544 - val_loss: 0.6699 - val_accuracy: 0.7455
# Epoch 51/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1262 - accuracy: 0.9504 - val_loss: 0.6748 - val_accuracy: 0.7422
# Epoch 52/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1141 - accuracy: 0.9568 - val_loss: 0.6756 - val_accuracy: 0.7433
# Epoch 53/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1187 - accuracy: 0.9560 - val_loss: 0.6788 - val_accuracy: 0.7400
# Epoch 54/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1163 - accuracy: 0.9558 - val_loss: 0.6688 - val_accuracy: 0.7455
# Epoch 55/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1196 - accuracy: 0.9552 - val_loss: 0.6761 - val_accuracy: 0.7422
# Epoch 56/100
# 117/117 [==============================] - 28s 239ms/step - loss: 0.1156 - accuracy: 0.9566 - val_loss: 0.6727 - val_accuracy: 0.7444
# Epoch 57/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1129 - accuracy: 0.9571 - val_loss: 0.6637 - val_accuracy: 0.7500
# Epoch 58/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1142 - accuracy: 0.9584 - val_loss: 0.6665 - val_accuracy: 0.7500
# Epoch 59/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1121 - accuracy: 0.9595 - val_loss: 0.6700 - val_accuracy: 0.7467
# Epoch 60/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1182 - accuracy: 0.9560 - val_loss: 0.6756 - val_accuracy: 0.7455
# Epoch 61/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1137 - accuracy: 0.9611 - val_loss: 0.6794 - val_accuracy: 0.7433
# Epoch 62/100
# 117/117 [==============================] - 29s 245ms/step - loss: 0.1047 - accuracy: 0.9617 - val_loss: 0.6762 - val_accuracy: 0.7444
# Epoch 63/100
# 117/117 [==============================] - 28s 239ms/step - loss: 0.1172 - accuracy: 0.9544 - val_loss: 0.6811 - val_accuracy: 0.7444
# Epoch 64/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1102 - accuracy: 0.9571 - val_loss: 0.6767 - val_accuracy: 0.7489
# Epoch 65/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1092 - accuracy: 0.9630 - val_loss: 0.6770 - val_accuracy: 0.7455
# Epoch 66/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1105 - accuracy: 0.9617 - val_loss: 0.6806 - val_accuracy: 0.7433
# Epoch 67/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1066 - accuracy: 0.9611 - val_loss: 0.6751 - val_accuracy: 0.7455
# Epoch 68/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1079 - accuracy: 0.9584 - val_loss: 0.6755 - val_accuracy: 0.7467
# Epoch 69/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1124 - accuracy: 0.9598 - val_loss: 0.6771 - val_accuracy: 0.7467
# Epoch 70/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1017 - accuracy: 0.9654 - val_loss: 0.6827 - val_accuracy: 0.7444
# Epoch 71/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1106 - accuracy: 0.9582 - val_loss: 0.6844 - val_accuracy: 0.7467
# Epoch 72/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1025 - accuracy: 0.9643 - val_loss: 0.6820 - val_accuracy: 0.7478
# Epoch 73/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1089 - accuracy: 0.9587 - val_loss: 0.6857 - val_accuracy: 0.7455
# Epoch 74/100
# 117/117 [==============================] - 28s 239ms/step - loss: 0.1046 - accuracy: 0.9625 - val_loss: 0.6944 - val_accuracy: 0.7444
# Epoch 75/100
# 117/117 [==============================] - 28s 239ms/step - loss: 0.1001 - accuracy: 0.9635 - val_loss: 0.6822 - val_accuracy: 0.7511
# Epoch 76/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1056 - accuracy: 0.9641 - val_loss: 0.6935 - val_accuracy: 0.7478
# Epoch 77/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.1022 - accuracy: 0.9630 - val_loss: 0.6826 - val_accuracy: 0.7489
# Epoch 78/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0981 - accuracy: 0.9665 - val_loss: 0.6896 - val_accuracy: 0.7489
# Epoch 79/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1079 - accuracy: 0.9603 - val_loss: 0.7013 - val_accuracy: 0.7455
# Epoch 80/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0990 - accuracy: 0.9643 - val_loss: 0.7013 - val_accuracy: 0.7444
# Epoch 81/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0966 - accuracy: 0.9678 - val_loss: 0.6940 - val_accuracy: 0.7467
# Epoch 82/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.1030 - accuracy: 0.9614 - val_loss: 0.6936 - val_accuracy: 0.7444
# Epoch 83/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0948 - accuracy: 0.9686 - val_loss: 0.6885 - val_accuracy: 0.7500
# Epoch 84/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.0976 - accuracy: 0.9633 - val_loss: 0.6895 - val_accuracy: 0.7455
# Epoch 85/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.0965 - accuracy: 0.9694 - val_loss: 0.6924 - val_accuracy: 0.7467
# Epoch 86/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.0923 - accuracy: 0.9667 - val_loss: 0.6984 - val_accuracy: 0.7455
# Epoch 87/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0970 - accuracy: 0.9667 - val_loss: 0.7005 - val_accuracy: 0.7444
# Epoch 88/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.1048 - accuracy: 0.9600 - val_loss: 0.6965 - val_accuracy: 0.7489
# Epoch 89/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1041 - accuracy: 0.9611 - val_loss: 0.7014 - val_accuracy: 0.7489
# Epoch 90/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0923 - accuracy: 0.9657 - val_loss: 0.7012 - val_accuracy: 0.7500
# Epoch 91/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.0901 - accuracy: 0.9697 - val_loss: 0.7109 - val_accuracy: 0.7478
# Epoch 92/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.1033 - accuracy: 0.9662 - val_loss: 0.7090 - val_accuracy: 0.7478
# Epoch 93/100
# 117/117 [==============================] - 29s 246ms/step - loss: 0.0939 - accuracy: 0.9649 - val_loss: 0.7071 - val_accuracy: 0.7489
# Epoch 94/100
# 117/117 [==============================] - 29s 247ms/step - loss: 0.0987 - accuracy: 0.9638 - val_loss: 0.7052 - val_accuracy: 0.7500
# Epoch 95/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0966 - accuracy: 0.9654 - val_loss: 0.7110 - val_accuracy: 0.7478
# Epoch 96/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.0955 - accuracy: 0.9659 - val_loss: 0.7131 - val_accuracy: 0.7467
# Epoch 97/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.0946 - accuracy: 0.9700 - val_loss: 0.7149 - val_accuracy: 0.7467
# Epoch 98/100
# 117/117 [==============================] - 28s 241ms/step - loss: 0.0905 - accuracy: 0.9700 - val_loss: 0.7121 - val_accuracy: 0.7478
# Epoch 99/100
# 117/117 [==============================] - 29s 249ms/step - loss: 0.0944 - accuracy: 0.9638 - val_loss: 0.7083 - val_accuracy: 0.7500
# Epoch 100/100
# 117/117 [==============================] - 28s 240ms/step - loss: 0.0947 - accuracy: 0.9659 - val_loss: 0.7081 - val_accuracy: 0.7522
